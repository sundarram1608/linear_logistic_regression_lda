# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)
sns.set_palette("muted")
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df1 = pd.read_csv('cubic_zirconia.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
df1.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df1.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %% [markdown]
# <b>Data Dictionary:
#
# Carat - Carat weight of the cubic zirconia.
#
# Cut - Describe the cut quality of the cubic zirconia. Quality is increasing order Fair, Good, Very Good, Premium, Ideal.
#
# Color - Colour of the cubic zirconia.With D being the worst and J the best.
#
# Clarity - Clarity refers to the absence of the Inclusions and Blemishes. (In order from Worst to Best in terms of avg price) IF, VVS1, VVS2, VS1, VS2, Sl1, Sl2, l1
#
# Depth - The Height of cubic zirconia, measured from the Culet to the table, divided by its average Girdle Diameter.
#
# Table - The Width of the cubic zirconia's Table expressed as a Percentage of its Average Diameter.
#
# Price - the Price of the cubic zirconia.
#
# X - Length of the cubic zirconia in mm.
#
# Y - Width of the cubic zirconia in mm.
#
# Z - Height of the cubic zirconia in mm.

# %%
df1.shape
# Out:
# (26967, 10)

# %%
df1.duplicated().sum()
# Out:
# 34

# %%
df1[df1.duplicated()]
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 4756    0.35    Premium     J     VS1   62.4   58.0  5.67  5.64  3.53    949
# 6215    0.71       Good     F     SI2   64.1   60.0  0.00  0.00  0.00   2130
# 8144    0.33      Ideal     G     VS1   62.1   55.0  4.46  4.43  2.76    854
# 8919    1.52       Good     E      I1   57.3   58.0  7.53  7.42  4.28   3105
# 9818    0.35      Ideal     F     VS2   61.4   54.0  4.58  4.54  2.80    906
# 10473   0.79      Ideal     G     SI1   62.3   57.0  5.90  5.85  3.66   2898
# 10500   1.00    Premium     F    VVS2   60.6   54.0  6.56  6.52  3.96   8924
# 12894   1.21    Premium     D     SI2   62.5   57.0  6.79  6.71  4.22   6505
# 13547   0.43      Ideal     G     VS1   61.9   55.0  4.84  4.86  3.00    943
# 13783   0.79      Ideal     G     SI1   62.3   57.0  5.90  5.85  3.66   2898
# 14389   0.60    Premium     D     SI2   62.0   57.0  5.43  5.35  3.34   1196
# ...

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (26933, 10)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26933 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26933 non-null  float64
#  1   cut      26933 non-null  object
#  2   color    26933 non-null  object
#  3   clarity  26933 non-null  object
#  4   depth    26236 non-null  float64
#  5   table    26933 non-null  float64
#  6   x        26933 non-null  float64
#  7   y        26933 non-null  float64
#  8   z        26933 non-null  float64
#  9   price    26933 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df1.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
round(df1.describe(),2)
# Out:
#           carat     depth     table         x         y         z     price
# count  26933.00  26236.00  26933.00  26933.00  26933.00  26933.00  26933.00
# mean       0.80     61.75     57.46      5.73      5.73      3.54   3937.53
# std        0.48      1.41      2.23      1.13      1.17      0.72   4022.55
# min        0.20     50.80     49.00      0.00      0.00      0.00    326.00
# 25%        0.40     61.00     56.00      4.71      4.71      2.90    945.00
# 50%        0.70     61.80     57.00      5.69      5.70      3.52   2375.00
# 75%        1.05     62.50     59.00      6.55      6.54      4.04   5356.00
# max        4.50     73.60     79.00     10.23     58.90     31.80  18818.00

# %% [markdown]
# Here, x,y,z has the min value to be 0 which is not logically correct. Hence we need to impute these values with median values. The distribution of all predictor variables seems to be more or less normally distributed, as the mean & median have very less variance.

# %%
df1[df1['x'] == 0]
# Out:
#        carat   cut color clarity  depth  table    x    y    z  price
# 5821    0.71  Good     F     SI2   64.1   60.0  0.0  0.0  0.0   2130
# 17506   1.14  Fair     G     VS1   57.5   67.0  0.0  0.0  0.0   6381

# %%
df1[df1['y'] == 0]
# Out:
#        carat   cut color clarity  depth  table    x    y    z  price
# 5821    0.71  Good     F     SI2   64.1   60.0  0.0  0.0  0.0   2130
# 17506   1.14  Fair     G     VS1   57.5   67.0  0.0  0.0  0.0   6381

# %%
df1[df1['z'] == 0]
# Out:
#        carat      cut color clarity  depth  table     x     y    z  price
# 5821    0.71     Good     F     SI2   64.1   60.0  0.00  0.00  0.0   2130
# 6034    2.02  Premium     H     VS2   62.7   53.0  8.02  7.95  0.0  18207
# 10827   2.20  Premium     H     SI1   61.2   59.0  8.42  8.37  0.0  17265
# 12498   2.18  Premium     H     SI2   59.4   61.0  8.49  8.45  0.0  12631
# 12689   1.10  Premium     G     SI2   63.0   59.0  6.50  6.47  0.0   3696
# 17506   1.14     Fair     G     VS1   57.5   67.0  0.00  0.00  0.0   6381
# 18194   1.01  Premium     H      I1   58.1   59.0  6.66  6.60  0.0   3167
# 23758   1.12  Premium     G      I1   60.4   59.0  6.71  6.67  0.0   2383

# %%
df1.drop(index=[5821,6034,10827,12498,12689,17506,18194,23758],axis=0,inplace=True)

# %%
df1.shape
# Out:
# (26925, 10)

# %%
df1.fillna(61.80,inplace=True)

# %%
df1.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
round(df1.describe(),2)
# Out:
#           carat     depth     table         x         y         z     price
# count  26925.00  26925.00  26925.00  26925.00  26925.00  26925.00  26925.00
# mean       0.80     61.75     57.46      5.73      5.73      3.54   3936.25
# std        0.48      1.39      2.23      1.13      1.16      0.72   4020.98
# min        0.20     50.80     49.00      3.73      3.71      1.07    326.00
# 25%        0.40     61.10     56.00      4.71      4.71      2.90    945.00
# 50%        0.70     61.80     57.00      5.69      5.70      3.52   2373.00
# 75%        1.05     62.50     59.00      6.55      6.54      4.04   5353.00
# max        4.50     73.60     79.00     10.23     58.90     31.80  18818.00

# %%
df1conti = df1[['carat','depth','table','x','y','z','price']]

# %%
a = np.arange(0,7)
df1conti_columns = df1conti.columns

# %%
j=0
plt.figure(figsize=(10,20))
for i in a:
    plt.subplot(7,2,j+1);
    sns.distplot(df1conti[df1conti_columns[i]],kde=True,bins=25);
    plt.title("Histogram Plot of {}".format(df1conti_columns[i]))
    j=j+1
    plt.subplot(7,2,j+1);
    sns.boxplot(df1conti[df1conti_columns[i]]);
    plt.title("BoxPlot of {}".format(df1conti_columns[i]))
    j=j+1
    plt.tight_layout();

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in df1conti_columns:
    lr,ur=remove_outlier(df1[column])
    df1[column]=np.where(df1[column]>ur,ur,df1[column])
    df1[column]=np.where(df1[column]<lr,lr,df1[column])

# %%
for column in df1conti_columns:
    lr,ur=remove_outlier(df1conti[column])
    df1conti[column]=np.where(df1conti[column]>ur,ur,df1conti[column])
    df1conti[column]=np.where(df1conti[column]<lr,lr,df1conti[column])

# %%
j=0
plt.figure(figsize=(10,20))
for i in a:
    plt.subplot(7,2,j+1);
    sns.distplot(df1conti[df1conti_columns[i]],kde=True,bins=25);
    plt.title("Histogram Plot of {}".format(df1conti_columns[i]))
    j=j+1
    plt.subplot(7,2,j+1);
    sns.boxplot(df1conti[df1conti_columns[i]]);
    plt.title("BoxPlot of {}".format(df1conti_columns[i]))
    j=j+1
    plt.tight_layout();

# %%
round(df1.describe(),2)
# Out:
#           carat     depth     table         x         y         z     price
# count  26925.00  26925.00  26925.00  26925.00  26925.00  26925.00  26925.00
# mean       0.79     61.75     57.44      5.73      5.73      3.54   3734.45
# std        0.46      1.22      2.16      1.13      1.12      0.70   3466.39
# min        0.20     59.00     51.50      3.73      3.71      1.19    326.00
# 25%        0.40     61.10     56.00      4.71      4.71      2.90    945.00
# 50%        0.70     61.80     57.00      5.69      5.70      3.52   2373.00
# 75%        1.05     62.50     59.00      6.55      6.54      4.04   5353.00
# max        2.03     64.60     63.50      9.31      9.28      5.75  11965.00

# %%
sns.heatmap(df1conti.corr(),annot=True, fmt='.2f', cmap='Blues',vmin=0,vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,15));
sns.pairplot(df1conti,diag_kind='kde');

# %%
#Count Plot to be visualized for categorical variables

# %%
df1cate = df1[['cut','color','clarity']]

# %%
b = np.arange(0,3)
df1cate_columns = df1cate.columns

# %%
plt.figure(figsize=(10,10))
for i in b:
    plt.subplot(2,2,i+1);
    bar_graph = sns.countplot(df1cate[df1cate_columns[i]]);
    bar_graph.bar_label(bar_graph.containers[0])
    plt.title("Count Plot of {}".format(df1cate_columns[i]))
    plt.tight_layout();

# %%
df1['color'].value_counts()
# Out:
# G    5650
# E    4916
# F    4722
# H    4091
# D    3341
# I    2765
# J    1440
# Name: color, dtype: int64

# %%
df1['clarity'].value_counts()
# Out:
# SI1     6564
# VS2     6092
# SI2     4561
# VS1     4086
# VVS2    2530
# VVS1    1839
# IF       891
# I1       362
# Name: clarity, dtype: int64

# %%
df1['cut'].value_counts()
# Out:
# Ideal        10805
# Premium       6880
# Very Good     6027
# Good          2434
# Fair           779
# Name: cut, dtype: int64

# %%
df1['color']=np.where(df1['color'] =='D', 'Worst', df1['color'])
df1['color']=np.where(df1['color'] =='E', 'Worst', df1['color'])
df1['color']=np.where(df1['color'] =='F', 'Worst', df1['color'])
df1['color']=np.where(df1['color'] =='G', 'Better', df1['color'])
df1['color']=np.where(df1['color'] =='H', 'Better', df1['color'])
df1['color']=np.where(df1['color'] =='I', 'Best', df1['color'])
df1['color']=np.where(df1['color'] =='J', 'Best', df1['color'])

# %%
df1['cut']=np.where(df1['cut'] =='Fair', '1', df1['cut'])
df1['cut']=np.where(df1['cut'] =='Good', '2', df1['cut'])
df1['cut']=np.where(df1['cut'] =='Very Good', '3', df1['cut'])
df1['cut']=np.where(df1['cut'] =='Premium', '4', df1['cut'])
df1['cut']=np.where(df1['cut'] =='Ideal', '5', df1['cut'])

# %%
df1['cut'] = df1['cut'].astype('int64')

# %%
df1['clarity']=np.where(df1['clarity'] =='I1', 'Best', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='SI2', 'Better', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='SI1', 'Better', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='VS2', 'Better', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='VS1', 'Better', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='VVS2', 'Worst', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='VVS1', 'Worst', df1['clarity'])
df1['clarity']=np.where(df1['clarity'] =='IF', 'Worst', df1['clarity'])

# %%
df1['color'].value_counts()
# Out:
# Worst     12979
# Better     9741
# Best       4205
# Name: color, dtype: int64

# %%
df1['clarity'].value_counts()
# Out:
# Better    21303
# Worst      5260
# Best        362
# Name: clarity, dtype: int64

# %%
plt.figure(figsize=(10,10))
for i in b:
    plt.subplot(2,2,i+1);
    bar_graph = sns.countplot(df1[df1cate_columns[i]]);
    bar_graph.bar_label(bar_graph.containers[0])
    plt.title("Count Plot of {}".format(df1cate_columns[i]))
    plt.tight_layout();

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26925 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26925 non-null  float64
#  1   cut      26925 non-null  int64
#  2   color    26925 non-null  object
#  3   clarity  26925 non-null  object
#  4   depth    26925 non-null  float64
#  5   table    26925 non-null  float64
#  6   x        26925 non-null  float64
#  7   y        26925 non-null  float64
#  8   z        26925 non-null  float64
#  9   price    26925 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 3.3+ MB

# %%
df1 = pd.get_dummies(df1, columns=['color','clarity'],drop_first=True)

# %%
df1.head()
# Out:
#    carat  cut  depth  table     x     y     z   price  color_Better  \
# 0   0.30    5   62.1   58.0  4.27  4.29  2.66   499.0             0
# 1   0.33    4   60.8   58.0  4.42  4.46  2.70   984.0             1
# 2   0.90    3   62.2   60.0  6.04  6.12  3.78  6289.0             0
# 3   0.42    5   61.6   56.0  4.82  4.80  2.96  1082.0             0
# 4   0.31    5   60.4   59.0  4.35  4.43  2.65   779.0             0
#
#    color_Worst  clarity_Better  clarity_Worst
# 0            1               1              0
# 1            0               0              1
# 2            1               0              1
# 3            1               1              0
# 4            1               0              1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26925 entries, 0 to 26966
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   carat           26925 non-null  float64
#  1   cut             26925 non-null  int64
#  2   depth           26925 non-null  float64
#  3   table           26925 non-null  float64
#  4   x               26925 non-null  float64
#  5   y               26925 non-null  float64
#  6   z               26925 non-null  float64
#  7   price           26925 non-null  float64
#  8   color_Better    26925 non-null  uint8
#  9   color_Worst     26925 non-null  uint8
#  10  clarity_Better  26925 non-null  uint8
#  11  clarity_Worst   26925 non-null  uint8
# dtypes: float64(7), int64(1), uint8(4)
# memory usage: 3.0 MB

# %%
X = df1.drop('price', axis=1) 
y = df1[['price']]

# %%
X.head()
# Out:
#    carat  cut  depth  table     x     y     z  color_Better  color_Worst  \
# 0   0.30    5   62.1   58.0  4.27  4.29  2.66             0            1
# 1   0.33    4   60.8   58.0  4.42  4.46  2.70             1            0
# 2   0.90    3   62.2   60.0  6.04  6.12  3.78             0            1
# 3   0.42    5   61.6   56.0  4.82  4.80  2.96             0            1
# 4   0.31    5   60.4   59.0  4.35  4.43  2.65             0            1
#
#    clarity_Better  clarity_Worst
# 0               1              0
# 1               0              1
# 2               0              1
# 3               1              0
# 4               0              1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=1)

# %%
data_train = pd.concat([X_train, y_train], axis=1)
data_test=pd.concat([X_test,y_test],axis=1)
data_train.head()
# Out:
#        carat  cut  depth  table     x     y     z  color_Better  color_Worst  \
# 5030    1.10    2   63.3   56.0  6.53  6.58  4.15             0            1
# 12108   1.01    3   64.0   56.0  6.30  6.38  4.06             0            1
# 20181   0.67    2   60.7   61.4  5.60  5.64  3.41             0            0
# 4712    0.76    2   59.0   63.0  6.05  5.97  3.47             1            0
# 2548    1.01    4   62.8   59.0  6.37  6.34  3.99             1            0
#
#        clarity_Better  clarity_Worst   price
# 5030                1              0  4065.0
# 12108               1              0  5166.0
# 20181               1              0  1708.0
# 4712                1              0  2447.0
# 2548                1              0  6618.0

# %%
expr= 'price ~ carat + cut + depth + table + x + y + z + color_Better + color_Worst + clarity_Better + clarity_Worst'

# %%
import statsmodels.formula.api as smf
lm1 = smf.ols(formula= expr, data = data_train).fit()
lm1.params
# Out:
# Intercept        -2651.075051
# carat             9196.612068
# cut                136.298113
# depth               -2.164993
# table              -22.729559
# x                -1927.736790
# y                 1749.710215
# z                 -735.900709
# color_Better       851.668896
# color_Worst       1189.721026
# clarity_Better    2569.214279
# clarity_Worst     3586.706987
# dtype: float64

# %%
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                 1.898e+04
# Date:                Sat, 26 Nov 2022   Prob (F-statistic):               0.00
# Time:                        15:51:30   Log-Likelihood:            -1.5684e+05
# No. Observations:               18847   AIC:                         3.137e+05
# Df Residuals:                   18835   BIC:                         3.138e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept      -2651.0751    879.802     -3.013      0.003   -4375.567    -926.583
# ...

# %%
mse = np.mean((lm1.predict(data_train.drop('price',axis=1))-data_train['price'])**2)
np.sqrt(mse)
# Out:
# 994.896591994911

# %%
y_pred = lm1.predict(data_test)

# %%
plt.scatter(y_test['price'], y_pred)
plt.show()

# %%
for i,j in np.array(lm1.params.reset_index()):
    print('({}) * {} +'.format(round(j,2),i),end=' ')
# Out:
# (-2651.08) * Intercept + (9196.61) * carat + (136.3) * cut + (-2.16) * depth + (-22.73) * table + (-1927.74) * x + (1749.71) * y + (-735.9) * z + (851.67) * color_Better + (1189.72) * color_Worst + (2569.21) * clarity_Better + (3586.71) * clarity_Worst +

# %%
y_pred_train = lm1.predict(data_train)

# %%
data_train['pred_price'] = y_pred_train

# %%
data_test['pred_price'] = y_pred

# %%
data_test.to_excel('testpred.xlsx', index=True)
data_train.to_excel('trainpred.xlsx', index=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 9196.612068110811
# The coefficient for cut is 136.2981127226916
# The coefficient for depth is -2.164992516452143
# The coefficient for table is -22.729559018784457
# The coefficient for x is -1927.7367901809926
# The coefficient for y is 1749.7102147129117
# The coefficient for z is -735.9007087825998
# The coefficient for color_Better is 851.6688956315184
# The coefficient for color_Worst is 1189.7210260201473
# The coefficient for clarity_Better is 2569.2142788909327
# The coefficient for clarity_Worst is 3586.706987192621

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -2651.0750505887277

# %%
# R square on training data
regression_model.score(X_train, y_train)
# Out:
# 0.9172354143691928

# %%
# R square on testing data
regression_model.score(X_test, y_test)
# Out:
# 0.9186029174767572

# %%
from sklearn import metrics

# %%
#RMSE on Training data
predicted_train=regression_model.fit(X_train, y_train).predict(X_train)
np.sqrt(metrics.mean_squared_error(y_train,predicted_train))
# Out:
# 994.896591994911

# %%
#RMSE on Testing data
predicted_test=regression_model.fit(X_train, y_train).predict(X_test)
np.sqrt(metrics.mean_squared_error(y_test,predicted_test))
# Out:
# 994.302755316158

# %%
from scipy.stats import zscore

X_train_scaled  = X_train.apply(zscore)
X_test_scaled = X_test.apply(zscore)
y_train_scaled = y_train.apply(zscore)
y_test_scaled = y_test.apply(zscore)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 1.2229588217778289
# The coefficient for cut is 0.0438460803792701
# The coefficient for depth is -0.0007632177582547746
# The coefficient for table is -0.014173371180421328
# The coefficient for x is -0.6249773890718382
# The coefficient for y is 0.5633927473697097
# The coefficient for z is -0.14744127094867182
# The coefficient for color_Better is 0.11835457617790977
# The coefficient for color_Worst is 0.1719019322505495
# The coefficient for clarity_Better is 0.30170085338455843
# The coefficient for clarity_Worst is 0.4108265492159944

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -6.783291499949349e-16

# %%
# Model score - R2 or coeff of determinant
# R^2=1–RSS / TSS

regression_model.score(X_test_scaled, y_test_scaled)
# Out:
# 0.9185755452904982

# %%
regression_model.score(X_train_scaled, y_train_scaled)
# Out:
# 0.9172354143691928

# %%
# Let us check the sum of squared errors by predicting value of y for training cases and 
# subtracting from the actual y for the training cases

mse = np.mean((regression_model.predict(X_test_scaled)-y_test_scaled)**2)

# %%
import math

math.sqrt(mse)
# Out:
# 0.28534970599161574

# %%
mse = np.mean((regression_model.predict(X_train_scaled)-y_train_scaled)**2)
math.sqrt(mse)
# Out:
# 0.2876883480970462

# %%
# predict mileage (mpg) for a set of attributes not in the training or test set
y_pred = regression_model.predict(X_test_scaled)

# %%
plt.scatter(y_test_scaled['price'], y_pred);

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)
sns.set_palette("muted")
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df2 = pd.read_csv('Holiday_Package.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 0           1               no   48412   30     8                  1
# 1           2              yes   37207   45     8                  0
# 2           3               no   58022   46     9                  0
# 3           4               no   66503   31    11                  2
# 4           5               no   66734   44    12                  0
#
#    no_older_children foreign
# 0                  1      no
# 1                  1      no
# 2                  0      no
# 3                  0      no
# 4                  2      no

# %%
df2.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df2.head()
# Out:
#   Holliday_Package  Salary  age  educ  no_young_children  no_older_children  \
# 0               no   48412   30     8                  1                  1
# 1              yes   37207   45     8                  0                  1
# 2               no   58022   46     9                  0                  0
# 3               no   66503   31    11                  2                  0
# 4               no   66734   44    12                  0                  2
#
#   foreign
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no

# %% [markdown]
# <b> Data Dictionary
#
# Holiday_Package   - Opted for Holiday Package yes/no?
#
# Salary            - Employee salary
#
# age               - Age in years
#
# edu               - Years of formal education
#
# no_young_children - The number of young children (younger than 7 years)
#
# no_older_children - Number of older children
#
# foreign 	      - foreigner Yes/No

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Holliday_Package   872 non-null    object
#  1   Salary             872 non-null    int64
#  2   age                872 non-null    int64
#  3   educ               872 non-null    int64
#  4   no_young_children  872 non-null    int64
#  5   no_older_children  872 non-null    int64
#  6   foreign            872 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 47.8+ KB

# %%
dups = df2.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
print(df2.shape)
# Out:
# Number of duplicate rows = 0
# (872, 7)

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Holliday_Package, Salary, age, educ, no_young_children, no_older_children, foreign]
# Index: []

# %%
for feature in df2.columns: 
    print(feature)
    print(df2[feature].value_counts())
    print('\n')
# Out:
# Holliday_Package
# no     471
# yes    401
# Name: Holliday_Package, dtype: int64
#
#
# Salary
# 46195     2
# 33357     2
# 39460     2
# 36976     2
# 40270     2
#          ..
# 38352     1
# 119644    1
# 96072     1
# 115431    1
# 74659     1
# Name: Salary, Length: 864, dtype: int64
#
#
# age
# 44    35
# 31    32
# 34    32
# 35    31
# 33    30
# 28    29
# 40    29
# 36    28
# 38    28
# 32    27
# 47    26
# 41    26
# 39    25
# 26    24
# 42    24
# 46    24
# 49    23
# 45    23
# 51    22
# 50    21
# 37    21
# 43    21
# 48    20
# 27    19
# 29    19
# 30    19
# 57    18
# 56    18
# 55    17
# 25    17
# 58    16
# 24    16
# 59    14
# 54    14
# 52    13
# 21    12
# 23    11
# 53    10
# 60    10
# 22     9
# 61     8
# 20     8
# 62     3
# Name: age, dtype: int64
#
#
# educ
# 8     157
# 12    124
# 9     114
# 11    100
# 10     90
# 5      67
# 4      50
# 13     43
# 7      31
# 14     25
# 6      21
# 15     15
# 3      11
# 16     10
# 2       6
# ...

# %%
df2.describe()
# Out:
#               Salary         age        educ  no_young_children  \
# count     872.000000  872.000000  872.000000         872.000000
# mean    47729.172018   39.955275    9.307339           0.311927
# std     23418.668531   10.551675    3.036259           0.612870
# min      1322.000000   20.000000    1.000000           0.000000
# 25%     35324.000000   32.000000    8.000000           0.000000
# 50%     41903.500000   39.000000    9.000000           0.000000
# 75%     53469.500000   48.000000   12.000000           0.000000
# max    236961.000000   62.000000   21.000000           3.000000
#
#        no_older_children
# count         872.000000
# mean            0.982798
# std             1.086786
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             2.000000
# max             6.000000

# %%
cols1 = ['Salary','age','educ']
for i in cols1:
    sns.boxplot(df2[i],whis=1.5)
    plt.grid()
    plt.show();

# %%
cols1 = ['Salary','age','educ']
for i in cols1:
    sns.distplot(df2[i],kde=  True)
    plt.grid()
    plt.show();

# %%
cols2 = ['no_young_children', 'no_older_children','foreign','Holliday_Package']
for i in cols2:
    bar_graph = sns.countplot(x =df2[i]);
    bar_graph.bar_label(bar_graph.containers[0]);
    plt.show();

# %%
cols2 = ['no_young_children', 'no_older_children','foreign']
for i in cols2:
    bar_graph = sns.countplot(x = i, hue='Holliday_Package',data=df2)
    bar_graph.bar_label(bar_graph.containers[0]);
    plt.show();

# %%
for i in cols1:
    sns.boxplot(df2['Holliday_Package'],df2[i],whis=1.5)
    plt.grid()
    plt.show();

# %%
sns.heatmap(df2.corr(), annot=True,fmt='.2f', cmap='Blues',vmin=0,vmax=1);

# %%
sns.pairplot(df2,diag_kind='hist' ,hue='Holliday_Package');

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Holliday_Package   872 non-null    object
#  1   Salary             872 non-null    int64
#  2   age                872 non-null    int64
#  3   educ               872 non-null    int64
#  4   no_young_children  872 non-null    int64
#  5   no_older_children  872 non-null    int64
#  6   foreign            872 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 47.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df2['Holliday_Package'] = LE.fit_transform(df2['Holliday_Package'])
df2['foreign'] = LE.fit_transform(df2['foreign'])
df2.head()
# Out:
#    Holliday_Package  Salary  age  educ  no_young_children  no_older_children  \
# 0                 0   48412   30     8                  1                  1
# 1                 1   37207   45     8                  0                  1
# 2                 0   58022   46     9                  0                  0
# 3                 0   66503   31    11                  2                  0
# 4                 0   66734   44    12                  0                  2
#
#    foreign
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(df2['Holliday_Package'].value_counts())
print(df2['foreign'].value_counts())
# Out:
# 0    471
# 1    401
# Name: Holliday_Package, dtype: int64
# 0    656
# 1    216
# Name: foreign, dtype: int64

# %%
X = df2.drop('Holliday_Package', axis=1)
y = df2['Holliday_Package']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.30,random_state=1,stratify = y)

# %%
Y_train.value_counts(1)
# Out:
# 0    0.539344
# 1    0.460656
# Name: Holliday_Package, dtype: float64

# %%
Y_test.value_counts(1)
# Out:
# 0    0.541985
# 1    0.458015
# Name: Holliday_Package, dtype: float64

# %% [markdown]
# # Logistic Regression

# %%
# Fit the Logistic Regression model
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
model = LogisticRegression(solver='newton-cg',max_iter=10000,penalty='none',verbose=True,n_jobs=2)
model.fit(X_train, Y_train)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    0.5s finished
# LogisticRegression(max_iter=10000, n_jobs=2, penalty='none', solver='newton-cg',
#                    verbose=True)

# %%
Ytrain_predict = model.predict(X_train)
Ytest_predict = model.predict(X_test)

# %%
Ytest_predict_prob=model.predict_proba(X_test)
pd.DataFrame(Ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.685350  0.314650
# 1  0.539470  0.460530
# 2  0.697043  0.302957
# 3  0.496350  0.503650
# 4  0.557724  0.442276

# %%
# Accuracy - Training Data
model.score(X_train, Y_train)
# Out:
# 0.6672131147540984

# %%
# predict probabilities
probs = model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(Y_train, probs)
print('AUC: %.4f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(Y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.7353

# %%
# Accuracy - Test Data
model.score(X_test, Y_test)
# Out:
# 0.6526717557251909

# %%
# predict probabilities
probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
test_auc = roc_auc_score(Y_test, probs)
print('AUC: %.4f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(Y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.7353

# %%
confusion_matrix(Y_train, Ytrain_predict)
# Out:
# array([[244,  85],
#        [118, 163]], dtype=int64)

# %%
print(classification_report(Y_train, Ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.74      0.71       329
#            1       0.66      0.58      0.62       281
#
#     accuracy                           0.67       610
#    macro avg       0.67      0.66      0.66       610
# weighted avg       0.67      0.67      0.66       610

# %%
confusion_matrix(Y_test, Ytest_predict)
# Out:
# array([[109,  33],
#        [ 58,  62]], dtype=int64)

# %%
print(classification_report(Y_test, Ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.77      0.71       142
#            1       0.65      0.52      0.58       120
#
#     accuracy                           0.65       262
#    macro avg       0.65      0.64      0.64       262
# weighted avg       0.65      0.65      0.65       262

# %% [markdown]
# ## LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
clf = LinearDiscriminantAnalysis()
model=clf.fit(X_train,Y_train)

# %%
# Training Data Class Prediction with a cut-off value of 0.5
pred_class_train = model.predict(X_train)

# Test Data Class Prediction with a cut-off value of 0.5
pred_class_test = model.predict(X_test)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(Y_train,pred_class_train)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(Y_test,pred_class_test)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',classification_report(Y_train,pred_class_train),'\n')
print('Classification Report of the test data:\n\n',classification_report(Y_test,pred_class_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70       329
#            1       0.65      0.58      0.61       281
#
#     accuracy                           0.66       610
#    macro avg       0.66      0.66      0.66       610
# weighted avg       0.66      0.66      0.66       610
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.64      0.77      0.70       142
#            1       0.64      0.49      0.56       120
#
#     accuracy                           0.64       262
#    macro avg       0.64      0.63      0.63       262
# weighted avg       0.64      0.64      0.63       262

# %%
# Training Data Probability Prediction
pred_prob_train = model.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = model.predict_proba(X_test)

# %%
pred_prob_train[:,1]
# Out:
# array([0.7381512 , 0.28961707, 0.38234291, 0.76483486, 0.46682945,
#        0.44346246, 0.37680169, 0.30948321, 0.61081614, 0.64208316,
#        0.25213217, 0.26469615, 0.39923017, 0.04631524, 0.23022974,
#        0.36249565, 0.53701148, 0.33367574, 0.63047975, 0.62551868,
#        0.62038047, 0.26045898, 0.8778445 , 0.33010529, 0.09907975,
#        0.83197262, 0.20726445, 0.7448485 , 0.52475576, 0.18602064,
#        0.34007289, 0.32707499, 0.37873484, 0.42874061, 0.31084381,
#        0.28746402, 0.11553843, 0.53094637, 0.47040748, 0.22122639,
#        0.26026817, 0.80975365, 0.51459465, 0.74029285, 0.79737631,
#        0.40099878, 0.298335  , 0.93065406, 0.44451279, 0.70660174,
#        0.75490574, 0.46875931, 0.77220783, 0.37565531, 0.22661608,
#        0.74188557, 0.26237721, 0.5247693 , 0.6721239 , 0.34088095,
#        0.62335813, 0.57741879, 0.54295979, 0.45085985, 0.56389786,
#        0.5965561 , 0.12149134, 0.57410954, 0.3890238 , 0.26157228,
# ...

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(Y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(Y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')
# Out:
# AUC for the Training Data: 0.733

# %%
# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(Y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(Y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.show()
# Out:
# AUC for the Test Data: 0.714
